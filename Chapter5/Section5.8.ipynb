# %%
# %matplotlib inline
from matplotlib import rcParams
rcParams["savefig.dpi"] = 150

# %%
from __future__ import print_function, division

# %%
import triangle
import numpy as np
import matplotlib.pyplot as pl
from IPython.display import display, Latex

# %%
np.random.seed(1234)

# %% [markdown]
# We want to compute an integral of the form
#
# $$\mathrm{E}_p [f(\theta)] = \int f(\theta)\,p(\theta\,|\,x)\,\mathrm{d}\theta \quad.$$
#
# We can evaluate this integral using Monte Carlo integration. If we can draw $N$ samples $\theta^{(n)} \sim q(\theta)$ then
#
# $$\mathrm{E}_p [f(\theta)] \approx \frac{1}{N} \sum_{n=1}^N \frac{f(\theta^{(n)})\,p(\theta^{(n)}\,|\,x)}{q(\theta^{(n)})} \quad.$$
#
# $q(\theta)$ needs to be *similar* to $p(\theta^{(n)}\,|\,x)$... best if we can actually sample from $p(\theta^{(n)}\,|\,x)$.

# %% [markdown]
# # Demo

# %% [markdown]
# We're going to fit a line to some data where the errorbars are underestimated.
#
# First, the truth:

# %%
truth = [1.1, -0.5, np.log(2.0)]

# %% [markdown]
# Generate some fake data.

# %%
x = np.sort(5 - 10*np.random.rand(10))
y = truth[0] * x + truth[1]
yerr = 0.2 + 0.2 * np.random.rand(len(x))
y += np.sqrt(yerr**2 + np.exp(2 * truth[2])) * np.random.randn(len(y))

# %%
pl.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0);

# %% [markdown]
# Let's start by ignoring the fact that the errorbars are **wrong**:

# %%
A = np.vander(x, 2)
C = np.diag(yerr**2)
S = np.linalg.inv(np.dot(A.T, np.linalg.solve(C, A)))
m, b = np.dot(S, np.dot(A.T, np.linalg.solve(C, y)))
display(Latex(r"$m_\mathrm{{LS}} = {0:.3f} \pm {1:.3f}$ ($m_\mathrm{{true}} = {2:.3f}$)".format(m, np.sqrt(S[0, 0]), truth[0])))
display(Latex(r"$b_\mathrm{{LS}} = {0:.3f} \pm {1:.3f}$ ($b_\mathrm{{true}} = {2:.3f}$)".format(b, np.sqrt(S[1, 1]), truth[1])));
# Out:
# $m_\mathrm{LS} = 0.966 \pm 0.034$ ($m_\mathrm{true} = 1.100$)
# $b_\mathrm{LS} = -0.666 \pm 0.098$ ($b_\mathrm{true} = -0.500$)

# %% [markdown]
# The log-likelihood function is:
#
# $$
# \ln p(y\,|\,x,\,\sigma,\,m,\,b,\,s) = C-\frac{1}{2} \sum_{n=1}^N \left [ \frac{(y_n-m\,x_n-b)^2}{\sigma_n^2 + s^2} + \ln (\sigma_n^2 + s^2) \right ]
# $$

# %%
def lnlike(p):
    m, b, lns = p
    model = m * x + b
    invar = 1.0 / (yerr**2 + np.exp(2*lns))
    return -0.5 * np.sum((y-model)**2 * invar - np.log(invar))

# %% [markdown]
# We're going to use uniform priors on $m$, $b$ and $\ln s$:

# %%
def lnprior(p):
    m, b, lns = p
    if -1 <= m <= 4 and -4 <= b <= 4 and -1 <= lns <= 4:
        return 0.0
    return -np.inf

# %% [markdown]
# Combine the prior and likelihood to get something proportional to the probability:

# %%
def lnprob(p):
    return lnprior(p) + lnlike(p)

# %% [markdown]
# Here we'll just confirm that the log-probability of the "truth" is higher than another random point.

# %%
print(lnprob(truth), lnprob(np.random.rand(3)))
# Out:
# -12.3852748235 -27.8541683954

# %% [markdown]
# ## Monte Carlo and Importance Sampling

# %% [markdown]
# We'll sample 50000 points from the (trivial) prior ($q(\theta) \propto 1$):

# %%
samples = np.array([-1, -4, -1])[None, :] + np.array([5, 8, 5])[None, :] * np.random.rand(50000, 3)

# %% [markdown]
# Compute the log-probability at each of these samples:

# %%
lnprobs = map(lnprob, samples)

# %% [markdown]
# The weight of each sample is proportional to $p(\theta^{(n)}\,|\,x) / q(\theta^{(n)}) = w^{(n)}$ and since none of our distirbutions are correctly normalized, our integral becomes:
#
# $$\mathrm{E}_p [f(\theta)] \approx \left[ \sum_n w^{(n)} \right]^{-1} \sum_{n=1}^N f(\theta^{(n)})\,w^{(n)}$$
#
# with weights computed as follows:

# %%
weights = np.exp(lnprobs - np.max(lnprobs))

# %% [markdown]
# Here are the results:

# %%
triangle.corner(samples, weights=weights, plot_datapoints=False,
                truths=truth, quantiles=[0.16, 0.5, 0.84],
                labels=["$m$", "$b$", "$\ln s$"]);
# Out:
# Quantiles:
# [(0.16, 0.7059996954268559), (0.5, 0.9849647950044855), (0.84, 1.2618780911986125)]
# Quantiles:
# [(0.16, -1.5368981365061984), (0.5, -0.7423023411589034), (0.84, 0.013770741469450034)]
# Quantiles:
# [(0.16, 0.6356548287373754), (0.5, 0.8737005800299837), (0.84, 1.143580903717028)]

# %%
for i, v in enumerate(["m", "b", "\ln s"]):
    norm = np.sum(weights)
    mu = np.sum(samples[:, i] * weights) / norm
    std = np.sqrt(np.sum((samples[:, i] - mu)**2 * weights) / norm)
    display(Latex(r"${0}_\mathrm{{MC}} = {1:.3f} \pm {2:.3f}$ (${0}_\mathrm{{true}} = {3:.3f}$)"
              .format(v, mu, std, truth[i])))
# Out:
# $m_\mathrm{MC} = 0.983 \pm 0.304$ ($m_\mathrm{true} = 1.100$)
# $b_\mathrm{MC} = -0.765 \pm 0.845$ ($b_\mathrm{true} = -0.500$)
# $\ln s_\mathrm{MC} = 0.887 \pm 0.262$ ($\ln s_\mathrm{true} = 0.693$)

# %% [markdown]
# This looks good until we see that most of our samples are wasted:

# %%
pl.hist(weights, 100, color="k", histtype="step")
pl.ylabel("number of samples")
pl.xlabel("sample weight");

# %% [markdown]
# ## Metropolis Algorithm

# %% [markdown]
# MCMC draws samples from $p(\theta\,|\,x)$ directly while only needing us to compute it up to a constant.
#
# **The algorithm**
#
# 1. start at some position $\theta^{(t)}$ in parameter space,
# 2. sample a new proposal position using some "proposal" distribution $\theta\prime \sim Q(\theta\prime\,|\,\theta^{(t)})$,
# 3. accept this proposal with probability
# $$r = \min \left (1, \frac{Q(\theta^{(t)}\,|\,\theta\prime)}{Q(\theta\prime\,|\,\theta^{(t)})} \, \frac{p(\theta\prime\,|\,x)}{p(\theta^{(t)}\,|\,x)} \right ) \quad, \mathrm{and}$$
# 4. iterate forever.
#
# The Metropolis algorithm assumes that $Q(\theta^{(t)}\,|\,\theta\prime) = Q(\theta\prime\,|\,\theta^{(t)})$ making the update even simpler. A simple pure Python implementation of a Metropolis step (assuming a Gaussian proposal) looks like:

# %%
def metropolis_update(lnprobfn, cov, x0, lp0):
    q = np.random.multivariate_normal(x0, cov)
    lp1 = lnprobfn(q)
    diff = lp1 - lp0
    if diff >= 0.0 or np.exp(diff) >= np.random.rand():
        return q, lp1, True
    return x0, lp0, False

# %% [markdown]
# We'll use an axis-aligned Gaussian as the proposal:

# %%
cov = np.diag([0.1, 0.1, 0.1])

# %% [markdown]
# And run for 50000 steps. I'll also be computing the acceptance fraction by keeping track of how many samples were saved.

# %%
count = 0
N = 50000
chain = np.empty((N, 3))
chain[0] = np.array(truth)
lp0 = lnprob(chain[0])
for i in range(1, N):
    chain[i], lp0, accept = metropolis_update(lnprob, cov, chain[i-1], lp0)
    count += accept
print("The acceptance fraction is {0}".format(float(count) / N))
# Out:
# The acceptance fraction is 0.4463

# %% [markdown]
# Finally, here are the results:

# %%
triangle.corner(chain, truths=truth, quantiles=[0.16, 0.5, 0.84],
                labels=["$m$", "$b$", "$\ln s$"]);
# Out:
# Quantiles:
# [(0.16, 0.697660298296639), (0.5, 0.98604868432934079), (0.84, 1.2779853478760508)]
# Quantiles:
# [(0.16, -1.544654749808045), (0.5, -0.7319445156893889), (0.84, 0.10796075446963969)]
# Quantiles:
# [(0.16, 0.63095694913351796), (0.5, 0.87022808834488152), (0.84, 1.1562669875909586)]

# %%
for i, v in enumerate(["m", "b", "\ln s"]):
    display(Latex(r"${0}_\mathrm{{MCMC}} = {1:.3f} \pm {2:.3f}$ (${0}_\mathrm{{true}} = {3:.3f}$)"
                  .format(v, np.mean(chain[:, i]), np.std(chain[:, i]), truth[i])))
# Out:
# $m_\mathrm{MCMC} = 0.990 \pm 0.310$ ($m_\mathrm{true} = 1.100$)
# $b_\mathrm{MCMC} = -0.715 \pm 0.886$ ($b_\mathrm{true} = -0.500$)
# $\ln s_\mathrm{MCMC} = 0.893 \pm 0.268$ ($\ln s_\mathrm{true} = 0.693$)

# %% [markdown]
# ## Using PyMC

# %%
import pymc

# %%
m = pymc.Uniform("m", -1, 4)
b = pymc.Uniform("b", -4, 4)
lns = pymc.Uniform("lns", -1, 4)

@pymc.deterministic(plot=False)
def invar(lns=lns):
    return 1.0 / (yerr**2 + np.exp(2*lns))

v = pymc.Normal("v", m * x + b, invar, observed=True, value=y)
model = dict(v=v, invar=invar, lns=lns, b=b, m=m)
S = pymc.MCMC(model)

# %%
S.sample(N)
# Out:
#  [                  2%                  ] 1123 of 50000 complete in 0.5 sec
#  [-                 5%                  ] 2545 of 50000 complete in 1.0 sec
#  [---               8%                  ] 4000 of 50000 complete in 1.5 sec
#  [----             10%                  ] 5431 of 50000 complete in 2.0 sec
#  [-----            13%                  ] 6856 of 50000 complete in 2.5 sec
#  [------           16%                  ] 8285 of 50000 complete in 3.0 sec
#  [-------          19%                  ] 9750 of 50000 complete in 3.5 sec
#  [--------         22%                  ] 11201 of 50000 complete in 4.0 sec
#  [---------        25%                  ] 12614 of 50000 complete in 4.5 sec
#  [----------       28%                  ] 14110 of 50000 complete in 5.0 sec
#  [-----------      31%                  ] 15564 of 50000 complete in 5.5 sec
#  [------------     34%                  ] 17004 of 50000 complete in 6.0 sec
#  [--------------   36%                  ] 18443 of 50000 complete in 6.5 sec
#  [---------------  39%                  ] 19852 of 50000 complete in 7.0 sec
#  [---------------- 42%                  ] 21314 of 50000 complete in 7.5 sec
#  [-----------------45%                  ] 22758 of 50000 complete in 8.0 sec
#  [-----------------48%                  ] 24177 of 50000 complete in 8.5 sec
#  [-----------------51%                  ] 25633 of 50000 complete in 9.0 sec
#  [-----------------54%                  ] 27090 of 50000 complete in 9.5 sec
#  [-----------------57%-                 ] 28532 of 50000 complete in 10.0 sec
#  [-----------------59%--                ] 29969 of 50000 complete in 10.5 sec
#  [-----------------62%---               ] 31437 of 50000 complete in 11.0 sec
#  [-----------------65%----              ] 32893 of 50000 complete in 11.5 sec
#  [-----------------68%------            ] 34338 of 50000 complete in 12.0 sec
#  [-----------------71%-------           ] 35764 of 50000 complete in 12.5 sec
#  [-----------------74%--------          ] 37228 of 50000 complete in 13.0 sec
#  [-----------------77%---------         ] 38678 of 50000 complete in 13.5 sec
#  [-----------------80%----------        ] 40102 of 50000 complete in 14.0 sec
#  [-----------------82%-----------       ] 41482 of 50000 complete in 14.5 sec
#  [-----------------85%------------      ] 42879 of 50000 complete in 15.0 sec
#  [-----------------88%-------------     ] 44318 of 50000 complete in 15.5 sec
#  [-----------------91%--------------    ] 45797 of 50000 complete in 16.0 sec
#  [-----------------94%---------------   ] 47048 of 50000 complete in 16.5 sec
#  [-----------------97%----------------  ] 48524 of 50000 complete in 17.0 sec
#  [-----------------99%----------------- ] 49967 of 50000 complete in 17.5 sec
#  [-----------------100%-----------------] 50000 of 50000 complete in 17.5 sec

# %%
pymc_chain = np.vstack((S.trace("m")[:], S.trace("b")[:], S.trace("lns")[:])).T

# %%
triangle.corner(pymc_chain, truths=truth, quantiles=[0.16, 0.5, 0.84],
                labels=["$m$", "$b$", "$\ln s$"]);
# Out:
# Quantiles:
# [(0.16, 0.69562287043452098), (0.5, 0.98820035932875361), (0.84, 1.2820463027106708)]
# Quantiles:
# [(0.16, -1.5569755575619411), (0.5, -0.72864771047292076), (0.84, 0.10565379240945053)]
# Quantiles:
# [(0.16, 0.63015369709336555), (0.5, 0.87588589500791614), (0.84, 1.1591525564481842)]

# %%
for i, v in enumerate(["m", "b", "\ln s"]):
    display(Latex(r"${0}_\mathrm{{PyMC}} = {1:.3f} \pm {2:.3f}$ (${0}_\mathrm{{true}} = {3:.3f}$)"
                  .format(v, np.mean(pymc_chain[:, i]), np.std(pymc_chain[:, i]), truth[i])))
# Out:
# $m_\mathrm{PyMC} = 0.991 \pm 0.320$ ($m_\mathrm{true} = 1.100$)
# $b_\mathrm{PyMC} = -0.726 \pm 0.892$ ($b_\mathrm{true} = -0.500$)
# $\ln s_\mathrm{PyMC} = 0.896 \pm 0.276$ ($\ln s_\mathrm{true} = 0.693$)

# %% [markdown]
# ## Using emcee

# %%
import emcee

# %%
ndim, nwalkers = 3, 10
p0 = [truth + 1e-1 * np.random.randn(ndim) for i in range(nwalkers)]

sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob)

# %%
sampler.run_mcmc(p0, N / nwalkers);

# %%
emcee_chain = sampler.flatchain

# %%
triangle.corner(emcee_chain, truths=truth, quantiles=[0.16, 0.5, 0.84],
                labels=["$m$", "$b$", "$\ln s$"]);
# Out:
# Quantiles:
# [(0.16, 0.70043205423972699), (0.5, 0.97727762748192104), (0.84, 1.2572849141106623)]
# Quantiles:
# [(0.16, -1.5707284500711722), (0.5, -0.74806394537694187), (0.84, 0.058258743734324221)]
# Quantiles:
# [(0.16, 0.60707949198805011), (0.5, 0.85579352764335725), (0.84, 1.1408298043100535)]

# %%
for i, v in enumerate(["m", "b", "\ln s"]):
    display(Latex(r"${0}_\mathrm{{emcee}} = {1:.3f} \pm {2:.3f}$ (${0}_\mathrm{{true}} = {3:.3f}$)"
                  .format(v, np.mean(emcee_chain[:, i]), np.std(pymc_chain[:, i]), truth[i])))
# Out:
# $m_\mathrm{emcee} = 0.979 \pm 0.320$ ($m_\mathrm{true} = 1.100$)
# $b_\mathrm{emcee} = -0.747 \pm 0.892$ ($b_\mathrm{true} = -0.500$)
# $\ln s_\mathrm{emcee} = 0.874 \pm 0.276$ ($\ln s_\mathrm{true} = 0.693$)
