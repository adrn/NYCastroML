# %% [markdown]
# # Chapter 5, Sections 5.2-5.4

# %% [markdown]
# ## 5.2. Bayesian Priors

# %% [markdown]
# ### 5.2.1. Priors Assigned by Formal Rules

# %% [markdown]
# There are several different kinds of priors that you might encounter.
#
# - **informative prior**: A prior that incorporates actual data.
# - **uninformative prior**: A prior that does not use actual data, but could still be meaningful, *e.g.* 'the parameter must be non-negative'.
#   - **improper prior**: A prior that cannot be formulated as a formal PDF.
#   - **flat prior**: A prior that is constant, $p(\theta|I) \propto C$.  These can be improper.
#   - **principle of indifference**: Assign equal probabilities to all, mutually-exclusive possibilities.
#   - **principle of consistency**: Priors assigned to 'location' parameters should be translation-invariant.  Priors assigned to 'scale' paramters should not depend on the choice of units.

# %% [markdown]
# ### 5.2.2. The Principle of Maximum Entropy

# %% [markdown]
# Maximum Entropy is used for cases where we have slightly more information about a parameter.  Maybe not enough for a fully-informative prior, but more than would warrant an uninformative prior.  This definition comes from Information Theory and is sometimes called "Shannon's Entropy".  For a discrete PDF:
#
# $$S=-\sum_{i=1}^N p_i \ln p_i$$
#
# For a continuous PDF:
#
# $$S = - \int_{-\infty}^\infty p(x) \ln \frac{p(x)}{m(x)} \mathrm{d}x$$
#
# What does the "measure", $m(x)$ *really* do?  Recall that a continuous PDF has units of $x^{-1}$.  So when we stuff $p(x)$ inside a logarithm, we have to cancel out those units.
#
# **Discuss**: Why does the continuous definition contain the measure, but the definition of the discrete entropy Equation (5.10) does not?  Yet later, the discrete entropy *does* contain the measure (Equation (5.15)).
#
# **Conclusion**: In some sense probability *is* a measure, so invoking yet another measure is a bit dogy.  Certainly though something is needed to cancel the units in the continuous example.
#
# Just for fun, let's solve Equation (5.17).
#
# $$p_i = m_i \exp\left(-1 - \lambda_0\right) \exp\left(i \lambda_1\right)$$
#
# Sum over $i$:
#
# $$\sum_{i=1}^6 p_i = \sum_{i=1}^6 m_i \exp\left(-1 - \lambda_0\right) \exp\left(i \lambda_1\right)$$
#
# Add the normalization constraint:
#
# $$1 = \exp\left(-1 - \lambda_0\right) \sum_{i=1}^6 m_i \exp\left(i \lambda_1\right)$$
#
# Rearrange:
#
# $$\exp\left(-1 - \lambda_0\right) = \left[\sum_{i=1}^6 m_i \exp\left(i \lambda_1\right) \right]^{-1}$$
#
# Now we go back to Equation (5.17), multiply by $i$ and then sum:
#
# $$\sum_{i=1}^6 i p_i = \sum_{i=1}^6 i m_i \exp\left(-1 - \lambda_0\right) \exp\left(i \lambda_1\right)$$
#
# Add the definition of $\mu$ and replace the $\lambda_0$ term:
#
# $$\mu = \frac{\sum_{i=1}^6 i m_i \exp\left(i \lambda_1\right)}{\sum_{i=1}^6 m_i \exp\left(i \lambda_1\right)} $$
#
# The $m_i$ are all the same, so they drop out:
#
# $$\mu = \frac{\sum_{i=1}^6 i \exp\left(i \lambda_1\right)}{\sum_{i=1}^6 \exp\left(i \lambda_1\right)} $$
#
# Note that if $\lambda_1 = 0$, $\mu = 3.5$, which is the expected mean for fair dice ($m_i = p_i = 1/6$).

# %%
i = arange(1,7,dtype='d')
l1 = linspace(-2,2,50)
d = 0
n = 0
for i in range(1,7):
    d += exp(i*l1)
    n += i*exp(i*l1)
mu = n/d
fig,ax = subplots(1,1,figsize=(8,6))
p = ax.plot(l1,mu,'k-')
foo = ax.set_xlabel('$\\lambda_1$')
foo = ax.set_ylabel('$\\mu$')

# %% [markdown]
# I'll leave the numerical inversion of the formula for $\mu$ as a function of $\lambda_1$ as an exercise.

# %% [markdown]
# ### 5.2.3. Conjugate Priors

# %% [markdown]
# Certain combinations of priors and likelihood functions have the same functional form.  Here's a list:
#
# | Prior    | Likelihood | Posterior |
# |----------|------------|-----------|
# | Gaussian | Gaussian   | Gaussian  |
# | Beta     | Binomial   | Beta      |
# | Gamma    | Poisson    | Gamma     |
#
# This can simplify your calculations!

# %% [markdown]
# ### 5.2.4. Empirical and Hierarchical Bayes Methods

# %% [markdown]
# - **Empirical Bayes**: Parameters of priors (*hyperparameters*) are estimated from the data.
# - **Heirarchical Bayes**: Priors on priors on priors...
#
# The citations are the best place to look for examples.

# %% [markdown]
# ## 5.3. Bayesian Parameter Uncertainty Quantification

# %% [markdown]
# ### 5.3.1. Posterior Intervals

# %% [markdown]
# **Credible Region Estimate**: find $a$, $b$ such that
#
# $$ \int_{-\infty}^a f(\theta)\mathrm{d}\theta = \int_b^\infty f(\theta)\mathrm{d}\theta = \alpha/2 $$
#
# then $1-\alpha$ is the *posterior interval*, giving the probability that $\theta$ has a value in the range $(a,b)$.
#
# In many cases, this interval has to be derived by sampling.

# %% [markdown]
# ### 5.3.2. Marginalization of Parameters

# %% [markdown]
# This is a pretty important aspect of Bayesian analysis, but this section only contains some definitions.  Practical examples are in Section 5.6.
#
# - **nuisance parameter**:  Any parameter of the model that is uninteresting in some way.
# - The posterior PDF for one parameter is obtained by integrating over *all* other parameters (nuisance or not).
# - The covariance for the interesting parameters is obtained by intergating over *only* the nuisance parameters.
# - All of these different integrals are called **marginalizations**.
#
# In general, the marginalized PDF for a particular parameter will be wider than the PDF obtained for a *specific value* of the other parameters.
#
# $$ \int p(x,y)\mathrm{d}y \;\mathrm{FT}\; \left.p(x,y)\right|_{y=y_1} $$
#
# where 'FT' is the 'fatter than' operator.

# %% [markdown]
# ## 5.4. Bayesian Model Selection

# %% [markdown]
# The **odds ratio** in favor of model $M_2$ over model $M_1$ is:
#
# $$ O_{21} = \frac{p(M_2|D,I)}{p(M_1|D,I)} $$
#
# The **marginal likelihood** (a.k.a. **evidence**) is:
#
# $$ E(M) \equiv p(D|M,I) = \int p(D|M,\theta,I) p(\theta|M,I) \mathrm{d}\theta $$
#
# and gives the probability that $D$ would be observed if $M$ were the correct model.  For two models, the **Bayes factor**, $B_{21} \equiv E(M_2)/E(M_1)$.
#
# The larger the odds ratio, the more decisive the evidence for $M_2$, but exactly *how* descisive is a subjective decision.
#
# Let's reproduce the coin flipping example.  Recall that
#
# - $M_1$: the coin has a known heads probability, $b_*$.  The prior for $M_1$ is proportional to $\delta(b - b_*)$.
# - $M_2$: the heads probability is unknown.  The prior for $M_2$ is uniform in the range $[0,1]$.
#
# $$ O_{21} = \int_0^1 \left(\frac{b}{b_*}\right)^k \left(\frac{1-b}{1-b_*}\right)^{N-k} \mathrm{d}b $$
#
# Let's try to evaluate this.  If you look closely, you'll see the integrand is the ratio of two different binomial distributions with different $b$, but the same $N$ and $k$.

# %%
from scipy import stats
#
# Set up the integral.  We'll use the binomial function in
# scipy to save some writing, but otherwise this is a 
# brute-force integral.
#
def integrand(b,bstar,N,k):
    num = stats.binom(N,b)
    den = stats.binom(N,bstar)
    return num.pmf(k)/den.pmf(k)
b = linspace(0,1,1000)
db = b[1]-b[0]
#
#
#
N_1 = 10
N_2 = 20
bstar_1 = 0.5
bstar_2 = 0.1
k_1 = arange(0,11)
k_2 = arange(0,21)
O21_11 = zeros(k_1.shape)
O21_12 = zeros(k_1.shape)
O21_21 = zeros(k_2.shape)
O21_22 = zeros(k_2.shape)

for kk in range(len(k_1)):
    O21_11[kk] = db*integrand(b,bstar_1,N_1,kk).sum()

for kk in range(len(k_2)):
    O21_21[kk] = db*integrand(b,bstar_1,N_2,kk).sum()

for kk in range(len(k_1)):
    O21_12[kk] = db*integrand(b,bstar_2,N_1,kk).sum()

for kk in range(len(k_2)):
    O21_22[kk] = db*integrand(b,bstar_2,N_2,kk).sum()
#
# Plot
#
fig,ax = subplots(1,2,figsize=(16,8))
pl0 = ax[0].semilogy(k_1,O21_11,'k-',k_1,O21_12,'k--',linewidth=2)
foo = ax[0].grid(True)
foo = ax[0].set_xlabel('Number of Heads, $k$')
foo = ax[0].set_xticks([0,2,4,6,8,10])
foo = ax[0].set_ylabel('Odds ratio, $O_{21}$')
foo = ax[0].set_ylim([0.1,10000])
foo = ax[0].set_title('Number of Flips, $N = 10$')
foo = ax[0].legend(['$b_* = 0.5$','$b_* = 0.1$',], loc=2)
pl1 = ax[1].semilogy(k_2,O21_21,'k-',k_2,O21_22,'k--',linewidth=2)
foo = ax[1].grid(True)
foo = ax[1].set_xlabel('Number of Heads, $k$')
foo = ax[1].set_xticks([0,4,8,12,16,20])
#foo = ax[1].set_ylabel('$O_{21}$')
foo = ax[1].set_ylim([0.1,10000])
foo = ax[1].set_title('Number of Flips, $N = 20$')

# %% [markdown]
# ### 5.4.1. Bayesian Hypothesis Testing

# %% [markdown]
# This is a specialized version of Bayesian Model Selection.  In this case one model is complementary to the other, $p(M_1) + p(M_2) = 1$.  Then we can call $M_1$ the "null" hypothesis and see if we can reject it.  The odds ratio reduces to:
#
# $$ O_{21} = B_{21} = \frac{p(D|M_1)}{p(D|M_2)} $$
#
# **Discuss**: is this formula even correct?
#
# **Conclusion**: Yes, there is a typo.  The model labels are swapped.  An erratum will be submitted.
#
# **Discuss**: the book says it is *impossible* to compute $p(D|M_2)$.  This makes no sense to me.  Sure, as Bayesians, we can't reject in the absence of alternative explanations, but $M_2$ *is* an alternate explanation.  How can it be a "model" otherwise?
#
# **Conclusion**: It is effectively impossible to do the computation *if* $M_2$ is the universe of all possible models that are not $M_1$.  However, there may be special cases where there really is only one possible alterantive model, in which case you can compute it.
#
# **Discuss**: "As shown in figure 5.1, the chosen parameters ($N = 20$, $k = 16$) correspond to the Bayesian odds ratio of ~10 in favor of the unfair coin hypothesis."  *Is this a mistake?*  How can an "unfair" coin have heads probability $b_* = 0.5$?  Do they actually mean "an unfair coin hypothesis that just happens to hypothesize a fair coin"?
#
# **Conclusion**: This is certainly confusing, and they may be inadvertently invoking a known paradox which can arise when one model incorporates another as a subset.

# %% [markdown]
# ### 5.4.2. Occam's Razor

# %% [markdown]
# The principle of selecting the simplest model that agrees with the data.  The Bayesian Odds Ratio naturally incorporates this principle.
#
# In the interests of time, we will simply refer to the worked-out example in the book.

# %% [markdown]
# ### 5.4.3. Information Criteria

# %% [markdown]
# The Bayesian Information Criterion is similar to the AIC discussed in the previous chapter.
#
# $$\mathrm{BIC} \equiv -2\ln \left[ L^0(M) \right] + k \ln N $$
#
# It is simpler to compute than the odds ratio, but makes certain assumptions about the likelihood.  BIC penalizes complex models more severely than the AIC.  Regardless of any assumptions, both the AIC and the BIC penalize unconstrained parameters.  Basically you should always use the odds ratio if you can.
