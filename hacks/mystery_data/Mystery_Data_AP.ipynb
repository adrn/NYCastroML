# %% [markdown]
# # Mystery Data: AP

# %% [markdown]
# Using data $$(x,y,\sigma)$$ in file file data.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import triangle

# %%
#Load the data from file
x,y,sigma_y = np.loadtxt("data.csv",delimiter=",").transpose()

# %%
plt.errorbar(x,y,sigma_y,linestyle="none",marker="o")
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

# %% [markdown]
# Likelihood function (from BAW, no copyright infringement intended):
#
# $$\ln p_{\mathrm{good},i} = - \frac{1}{2} \left[ \frac{(y_i - (a x_i + b))^2}{\sigma_i^2} + \ln \left(2 \pi \sigma_i^2 \right) \right]$$
#
# $$\ln p_{\mathrm{bad},i} = - \frac{1}{2} \left[ \frac{(y_i - (a x_i + b))^2}{\sigma_{\mathrm{bad}}^2} + \ln \left(2 \pi \sigma_{\mathrm{bad}}^2 \right) \right]$$
#
# $$\ln p(X|\theta) = \sum_i \ln \left[ (1-Q_{\mathrm{bad}}) p_{\mathrm{good},i} + Q_{\mathrm{bad}} p_{\mathrm{bad},i} \right] $$
#
# Priors:
#
# $$p(a) = U(0,50)$$
#
# $$p(b) = U(4,8)$$
#
# $$p(\ln \sigma_{\mathrm{bad}}) = U(-2,2)$$
#
# $$p(Q_{\mathrm{bad}}) = U(0,1)$$

# %%
#Code up the above likelihood function
from scipy.misc import logsumexp

def logLikelihood(p,x,y,sigma_y):

	#Parameters are p=(a,b,Qbad,log(sigma_bad))
	a = p[0]
	b = p[1]
	Qbad = p[2]
	logSigmabad = p[3]

	#Uniform on a=U(0,50) ; b=U(4,8); Qbad=U(0,1) ; logSigmaBad=U(-2,2)
	if a<0. or a>50.:
		return -np.inf

	if b<4. or b>8.:
		return -np.inf

	if Qbad<0. or Qbad>1.:
		return -np.inf

	if logSigmabad<-2. or logSigmabad>2.:
		return -np.inf

	#Pgood
	logPgood = -0.5*(((y-a*x-b)/sigma_y)**2 + np.log(2*np.pi*sigma_y**2))
	#Pbad
	logPbad = -0.5*(((y-a*x-b)/np.exp(logSigmabad))**2 + np.log(2*np.pi) + 2*logSigmabad)

	#Data likelihood
	w = np.ones((2,len(x)))
	w[0] = 1.-Qbad
	w[1] = Qbad
	
	return logsumexp(np.vstack((logPgood,logPbad)),b=w,axis=0).sum()

# %%
#Setup the MCMC sampler using emcee
import emcee

#4 parameters (a,b,Qbad,logSigmaBad)
ndim = 4
#32 walkers
nwalkers = 32
#Chain starts from here (initial positions of the walkers)
p0 = np.ones((nwalkers,ndim))
p0[:,0] = np.random.uniform(low=0.0,high=50.0,size=nwalkers)
p0[:,1] = np.random.uniform(low=4.0,high=8.0,size=nwalkers)
p0[:,2] = np.random.uniform(low=0.0,high=1.0,size=nwalkers)
p0[:,3] = np.random.uniform(low=-2.0,high=2.0,size=nwalkers)

#Sampler initialization
sampler = emcee.EnsembleSampler(nwalkers,ndim,logLikelihood,args=[x,y,sigma_y])

# %%
#Burn in step
pos,prob,state = sampler.run_mcmc(p0,1000)
sampler.reset()

# %%
#Run the chain after the burn in
sampler.run_mcmc(pos, 10000)
# Out:
# (array([[  6.12539499e-01,   5.93685369e+00,   4.25267736e-01,
#          -9.98874502e-01],
#        [  6.13353655e-01,   5.92120182e+00,   2.57191498e-01,
#          -1.46613513e+00],
#        [  5.96818231e-01,   5.94741171e+00,   2.46360728e-01,
#          -1.33624436e+00],
#        [  6.10289634e-01,   5.98904423e+00,   3.70196131e-01,
#          -1.74095568e+00],
#        [  6.03091571e-01,   5.94328243e+00,   4.37718449e-01,
#          -1.40153221e+00],
#        [  6.02240081e-01,   6.02747921e+00,   6.46601416e-01,
#          -1.28479117e+00],
#        [  6.02345318e-01,   6.00769902e+00,   3.22223020e-01,
#          -1.06494701e+00],
#        [  6.05020309e-01,   5.94104752e+00,   2.22469484e-01,
#          -1.27637370e+00],
#        [  5.71113172e-01,   6.03814905e+00,   2.02173466e-01,
#          -1.78011765e+00],
#        [  6.01848151e-01,   5.95953621e+00,   1.82068237e-01,
#          -1.78724356e+00],
#        [  5.55260378e-01,   6.07743665e+00,   2.54130624e-01,
#          -1.22955833e+00],
#        [  5.88910481e-01,   5.97030114e+00,   2.57506686e-01,
#          -1.14124356e+00],
#        [  5.84622591e-01,   6.00428026e+00,   2.86777389e-01,
#          -1.91260327e+00],
#        [  5.46480958e-01,   6.10379488e+00,   3.59777675e-01,
#          -1.93500973e+00],
#        [  5.35149791e-01,   6.07768199e+00,   2.90086325e-01,
#          -1.63919394e+00],
#        [  5.86693907e-01,   5.98620581e+00,   1.43358377e-01,
#          -1.66404439e+00],
#        [  5.67837578e-01,   6.09031354e+00,   1.15345179e-01,
#          -1.04486532e+00],
#        [  5.54889529e-01,   6.05232216e+00,   6.33637266e-01,
#          -1.32763158e+00],
#        [  5.43151983e-01,   6.10387382e+00,   4.22285709e-01,
#          -1.53941342e+00],
#        [  5.48151798e-01,   6.10145514e+00,   1.64505434e-03,
#           3.08974213e-01],
#        [  5.70720763e-01,   6.01886162e+00,   2.21282971e-01,
#          -1.38790475e+00],
#        [  5.79423663e-01,   6.01976640e+00,   3.64066381e-01,
#          -1.56330665e+00],
#        [  5.95683860e-01,   5.97424193e+00,   2.41079087e-01,
#          -1.49971524e+00],
#        [  5.53199780e-01,   6.07607939e+00,   1.93283323e-01,
#          -1.76007788e+00],
#        [  5.48372014e-01,   6.08338876e+00,   1.86168905e-01,
#          -9.21946398e-01],
#        [  6.00107133e-01,   5.95423437e+00,   2.49433378e-01,
#          -1.39382178e+00],
#        [  5.67542097e-01,   6.09715311e+00,   4.45943457e-01,
#          -9.02229663e-01],
#        [  6.04849594e-01,   5.90977231e+00,   1.18064777e-01,
#          -1.63647031e+00],
#        [  5.62140312e-01,   6.02773571e+00,   1.13436602e-01,
#          -1.30733910e+00],
#        [  5.55546324e-01,   6.05864424e+00,   1.54419700e-01,
#         428127164, 2231536508, 2178848201, 2930406367,   55220638,
#         655467283, 3197799108, 2829054978, 3087388779, 1534108280,
#        2429087887, 2053193976, 2826926478, 4173521897, 3018649258,
#        1171929199, 2299526001, 1069049173,  311148449, 4021117057,
#         760460949, 3346869946,  517479301, 1697024444,  582072399,
#        1226715438, 2622370825, 1566543676, 1885621034, 2079271242,
#        2701082629, 1146049495, 1058264575, 3953990534,  991937096,
#        2494634204, 2390207079, 2846837451, 2573070319, 3911315514,
#         365667831, 1234443084, 3530499009, 4125235549, 1029288115,
#        4121892492, 3241161005, 1980545173, 2140070245, 2350175560,
#        4147806504, 4137947362, 1996605384,  899899282, 2046204175,
#         884447225,  812969961,  385908576, 3915101143, 3312004065,
#         539126746,  364366657, 3488980905, 3192481481, 3200741763,
#         968396772, 2583809322,  899785560,  496781995, 2914981946,
#        3402553557, 1439902978, 3578356772, 2519302362, 1618844096,
#        4046569202,  265177108, 1641733819, 3240356911, 3694176863,
#        3377430534,  171268841, 1757447864, 4095430668, 1148229824,
#        1476381496, 4277861267, 1734348393, 2435153712, 1903801276,
#         904697435, 2504730178, 2854555628, 1850833585,  997246356,
#        3556138607, 1028164751, 2440721282, 2414427142, 1703236810,
#        1473917491, 2397216227,  785555685, 2503536421,   17191463,
#         898458146, 3651526983, 3942623609, 2067400597, 3804209714,
#        1474704724, 1442402813, 3128237350,  222188907, 1699795046,
#        4011807594,  620552960, 1974570961, 2079162187, 2900389466,
#        1365252762, 3373915624, 2952297216, 1533252128, 2221252699,
#         510725672, 3969987360, 4026089127, 2500954877, 1884254256,
#         720184879, 2650434289, 2222734691,  132798570, 1985956286,
#        4294825270,  649725332,  360088730,  262357972, 3598947723,
#        2938648308, 1062362693, 2334401424, 3151478518, 3277511761,
#         690882880,  969031028, 2479766433, 2542842840, 1445639872,
#        1815964304, 3435708142, 2873739770,  865131626,  413190155,
#        2720568701, 3931897786, 1491716213, 3980747295,  422259623,
#        3660327011, 3267926001,  162682803, 1193490168, 4051500301,
#        2928184388, 3175156516, 2344625548, 3221943616, 4072893094,
#        3342991636, 2572418262, 2828792131, 1151447697, 3051185647,
#        3854035259,  903571933,  685272467,  494515867, 3745460209,
#        2380639400, 1973511215, 1863835535, 2360488839,  184733147,
#        4257458217, 1626281412,  430257542, 2636135936, 1825250561,
#         353660745, 4042289620, 3313146084, 3864590314, 2898363781,
#        2500461926, 2568963360, 1439163799, 3045761703, 1587177268,
#        3921405446, 4089596655,  907889365,  863673803, 4063278966,
#        3506771691, 3427511306, 2879925799, 1799978613], dtype=uint32),
#   320,
#   0,
#   0.0))

# %%
#Plot the results using triangle
true_params = (0.5,6,0.5,0.0)
extents = [(0.5*truth,1.5*truth) for truth in true_params]
figure = triangle.corner(sampler.flatchain,labels=[r"$a$",r"$b$",r"$Q_{bad}$",r"$\log{\sigma_{bad}}$"],truths=true_params,plot_datapoints=False)
